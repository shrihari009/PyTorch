# %%
import torch

# %%
features = torch.randint(10,100,(6,3))

# %%
features.float()
# Out:
# tensor([[77., 25., 52.],
#         [65., 89., 28.],
#         [63., 97., 17.],
#         [52., 55., 59.],
#         [77., 69., 13.],
#         [20., 79., 63.]])

# %%
target = torch.randint(40, 60, (6,1))

# %%
target
# Out:
# tensor([[59],
#         [45],
#         [54],
#         [58],
#         [42],
#         [49]])

# %%
w = torch.randn(1, 3, requires_grad=True)
w
# Out:
# tensor([[-0.0304,  1.8984,  0.1026]], requires_grad=True)

# %%
w1 = w

# %%
b = torch.randn(1, requires_grad=True)
b
# Out:
# tensor([-1.0613], requires_grad=True)

# %%
b1 = b

# %%
def linear_model(x):
  return x.float() @ w1.t() + b1

# %%
pred = linear_model(features)

# %%
pred.dtype
# Out:
# torch.float32

# %%
def mse(predt, tar):
  diff = predt - tar
  return torch.sum(diff*diff)/diff.numel()

# %%
loss = mse(pred, target)
loss
# Out:
# tensor(8876.5928, grad_fn=<DivBackward0>)

# %%
loss.backward()

# %%
w1.grad
# Out:
# tensor([[ 8942.3027, 13458.3770,  5296.9224]])

# %%
b1.grad
# Out:
# tensor([161.8680])

# %%
lr = 0.0001

# %%
w1.data -= w1.grad*lr

# %%
b1.data -= b1.grad*lr

# %%
mse(linear_model(features), target)
# Out:
# tensor(8084.9702, grad_fn=<DivBackward0>)

# %%
for i in range(100):
  preds = linear_model(features)
  loss = mse(preds, target)
  loss.backward()
  with torch.no_grad():
    w1.data -= w1.grad * lr
    b1.data -= b1.grad * lr
    print("w1: ",w1,
          "\nb1: ",b1)
    w1.grad.zero_()
    b1.grad.zero_()
# Out:
# w1:  tensor([[-0.7493,  0.2557, -0.2676]], requires_grad=True)
# b1:  tensor([-1.0766], requires_grad=True)
# w1:  tensor([[0.3532, 1.4059, 0.4336]], requires_grad=True)
# b1:  tensor([-1.0588], requires_grad=True)
# w1:  tensor([[-0.5850,  0.1229, -0.1391]], requires_grad=True)
# b1:  tensor([-1.0753], requires_grad=True)
# w1:  tensor([[0.4427, 1.2232, 0.5108]], requires_grad=True)
# b1:  tensor([-1.0586], requires_grad=True)
# w1:  tensor([[-0.4525,  0.0273, -0.0390]], requires_grad=True)
# b1:  tensor([-1.0742], requires_grad=True)
# w1:  tensor([[0.5072, 1.0768, 0.5653]], requires_grad=True)
# b1:  tensor([-1.0585], requires_grad=True)
# w1:  tensor([[-0.3449, -0.0402,  0.0395]], requires_grad=True)
# b1:  tensor([-1.0732], requires_grad=True)
# w1:  tensor([[0.5528, 0.9586, 0.6029]], requires_grad=True)
# b1:  tensor([-1.0585], requires_grad=True)
# w1:  tensor([[-0.2570, -0.0865,  0.1016]], requires_grad=True)
# b1:  tensor([-1.0724], requires_grad=True)
# w1:  tensor([[0.5840, 0.8624, 0.6280]], requires_grad=True)
# b1:  tensor([-1.0585], requires_grad=True)
# w1:  tensor([[-0.1845, -0.1168,  0.1512]], requires_grad=True)
# b1:  tensor([-1.0717], requires_grad=True)
# w1:  tensor([[0.6041, 0.7833, 0.6440]], requires_grad=True)
# b1:  tensor([-1.0587], requires_grad=True)
# w1:  tensor([[-0.1243, -0.1351,  0.1912]], requires_grad=True)
# b1:  tensor([-1.0711], requires_grad=True)
# w1:  tensor([[0.6159, 0.7178, 0.6531]], requires_grad=True)
# b1:  tensor([-1.0588], requires_grad=True)
# w1:  tensor([[-0.0739, -0.1445,  0.2239]], requires_grad=True)
# b1:  tensor([-1.0706], requires_grad=True)
# w1:  tensor([[0.6214, 0.6629, 0.6574]], requires_grad=True)
# b1:  tensor([-1.0590], requires_grad=True)
# w1:  tensor([[-0.0312, -0.1473,  0.2510]], requires_grad=True)
# b1:  tensor([-1.0702], requires_grad=True)
# w1:  tensor([[0.6224, 0.6164, 0.6582]], requires_grad=True)
# b1:  tensor([-1.0593], requires_grad=True)
# w1:  tensor([[ 0.0052, -0.1453,  0.2736]], requires_grad=True)
# b1:  tensor([-1.0697], requires_grad=True)
# w1:  tensor([[0.6199, 0.5767, 0.6564]], requires_grad=True)
# b1:  tensor([-1.0595], requires_grad=True)
# w1:  tensor([[ 0.0366, -0.1399,  0.2928]], requires_grad=True)
# b1:  tensor([-1.0694], requires_grad=True)
# w1:  tensor([[0.6149, 0.5423, 0.6529]], requires_grad=True)
# b1:  tensor([-1.0597], requires_grad=True)
# w1:  tensor([[ 0.0639, -0.1321,  0.3093]], requires_grad=True)
# b1:  tensor([-1.0690], requires_grad=True)
# w1:  tensor([[0.6083, 0.5124, 0.6481]], requires_grad=True)
# b1:  tensor([-1.0599], requires_grad=True)
# w1:  tensor([[ 0.0879, -0.1225,  0.3237]], requires_grad=True)
# b1:  tensor([-1.0687], requires_grad=True)
# w1:  tensor([[0.6004, 0.4859, 0.6427]], requires_grad=True)
# b1:  tensor([-1.0601], requires_grad=True)
# w1:  tensor([[ 0.1091, -0.1119,  0.3363]], requires_grad=True)
# b1:  tensor([-1.0684], requires_grad=True)
# w1:  tensor([[0.5918, 0.4624, 0.6367]], requires_grad=True)
# b1:  tensor([-1.0603], requires_grad=True)
# w1:  tensor([[ 0.1280, -0.1007,  0.3475]], requires_grad=True)
# b1:  tensor([-1.0682], requires_grad=True)
# w1:  tensor([[0.5827, 0.4414, 0.6305]], requires_grad=True)
# b1:  tensor([-1.0605], requires_grad=True)
# w1:  tensor([[ 0.1451, -0.0892,  0.3576]], requires_grad=True)
# b1:  tensor([-1.0679], requires_grad=True)
# w1:  tensor([[0.5734, 0.4223, 0.6242]], requires_grad=True)
# b1:  tensor([-1.0607], requires_grad=True)
# w1:  tensor([[ 0.1604, -0.0776,  0.3667]], requires_grad=True)
# b1:  tensor([-1.0677], requires_grad=True)
# w1:  tensor([[0.5640, 0.4050, 0.6180]], requires_grad=True)
# b1:  tensor([-1.0609], requires_grad=True)
# w1:  tensor([[ 0.1745, -0.0660,  0.3751]], requires_grad=True)
# b1:  tensor([-1.0675], requires_grad=True)
# w1:  tensor([[0.5548, 0.3892, 0.6118]], requires_grad=True)
# b1:  tensor([-1.0611], requires_grad=True)
# w1:  tensor([[ 0.1873, -0.0547,  0.3827]], requires_grad=True)
# b1:  tensor([-1.0673], requires_grad=True)
# w1:  tensor([[0.5457, 0.3747, 0.6059]], requires_grad=True)
# b1:  tensor([-1.0613], requires_grad=True)
# w1:  tensor([[ 0.1991, -0.0438,  0.3898]], requires_grad=True)
# b1:  tensor([-1.0671], requires_grad=True)
# w1:  tensor([[0.5369, 0.3613, 0.6001]], requires_grad=True)
# b1:  tensor([-1.0614], requires_grad=True)
# w1:  tensor([[ 0.2099, -0.0332,  0.3963]], requires_grad=True)
# b1:  tensor([-1.0670], requires_grad=True)
# w1:  tensor([[0.5284, 0.3489, 0.5946]], requires_grad=True)
# b1:  tensor([-1.0616], requires_grad=True)
# w1:  tensor([[ 0.2200, -0.0229,  0.4024]], requires_grad=True)
# b1:  tensor([-1.0668], requires_grad=True)
# w1:  tensor([[0.5202, 0.3373, 0.5893]], requires_grad=True)
# b1:  tensor([-1.0617], requires_grad=True)
# w1:  tensor([[ 0.2294, -0.0132,  0.4080]], requires_grad=True)
# b1:  tensor([-1.0667], requires_grad=True)
# w1:  tensor([[0.5123, 0.3266, 0.5842]], requires_grad=True)
# b1:  tensor([-1.0619], requires_grad=True)
# w1:  tensor([[ 0.2381, -0.0038,  0.4133]], requires_grad=True)
# b1:  tensor([-1.0665], requires_grad=True)
# w1:  tensor([[0.5048, 0.3166, 0.5794]], requires_grad=True)
# b1:  tensor([-1.0620], requires_grad=True)
# w1:  tensor([[0.2462, 0.0050, 0.4182]], requires_grad=True)
# b1:  tensor([-1.0664], requires_grad=True)
# w1:  tensor([[0.4977, 0.3072, 0.5749]], requires_grad=True)
# b1:  tensor([-1.0621], requires_grad=True)
# w1:  tensor([[0.2538, 0.0135, 0.4229]], requires_grad=True)
# b1:  tensor([-1.0662], requires_grad=True)
# w1:  tensor([[0.4909, 0.2984, 0.5706]], requires_grad=True)
# b1:  tensor([-1.0623], requires_grad=True)
# w1:  tensor([[0.2609, 0.0215, 0.4272]], requires_grad=True)
# b1:  tensor([-1.0661], requires_grad=True)
# w1:  tensor([[0.4844, 0.2902, 0.5665]], requires_grad=True)
# b1:  tensor([-1.0624], requires_grad=True)
# w1:  tensor([[0.2676, 0.0291, 0.4313]], requires_grad=True)
# b1:  tensor([-1.0660], requires_grad=True)
# w1:  tensor([[0.4783, 0.2824, 0.5626]], requires_grad=True)
# b1:  tensor([-1.0625], requires_grad=True)
# w1:  tensor([[0.2738, 0.0363, 0.4351]], requires_grad=True)
# b1:  tensor([-1.0659], requires_grad=True)
# w1:  tensor([[0.4725, 0.2752, 0.5589]], requires_grad=True)
# b1:  tensor([-1.0626], requires_grad=True)
# w1:  tensor([[0.2797, 0.0431, 0.4388]], requires_grad=True)
# b1:  tensor([-1.0658], requires_grad=True)
# w1:  tensor([[0.4670, 0.2684, 0.5555]], requires_grad=True)
# b1:  tensor([-1.0627], requires_grad=True)
# w1:  tensor([[0.2852, 0.0496, 0.4422]], requires_grad=True)
# b1:  tensor([-1.0657], requires_grad=True)
# w1:  tensor([[0.4618, 0.2620, 0.5522]], requires_grad=True)
# b1:  tensor([-1.0627], requires_grad=True)
# w1:  tensor([[0.2904, 0.0557, 0.4454]], requires_grad=True)
# b1:  tensor([-1.0656], requires_grad=True)
# w1:  tensor([[0.4569, 0.2559, 0.5491]], requires_grad=True)
# b1:  tensor([-1.0628], requires_grad=True)
# w1:  tensor([[0.2953, 0.0614, 0.4484]], requires_grad=True)
# b1:  tensor([-1.0656], requires_grad=True)
# w1:  tensor([[0.4523, 0.2502, 0.5462]], requires_grad=True)
# b1:  tensor([-1.0629], requires_grad=True)
# w1:  tensor([[0.2999, 0.0669, 0.4512]], requires_grad=True)
# b1:  tensor([-1.0655], requires_grad=True)
# w1:  tensor([[0.4479, 0.2449, 0.5435]], requires_grad=True)
# b1:  tensor([-1.0630], requires_grad=True)
# w1:  tensor([[0.3042, 0.0720, 0.4539]], requires_grad=True)
# b1:  tensor([-1.0654], requires_grad=True)
# w1:  tensor([[0.4438, 0.2399, 0.5409]], requires_grad=True)
# b1:  tensor([-1.0630], requires_grad=True)
# w1:  tensor([[0.3082, 0.0768, 0.4564]], requires_grad=True)
# b1:  tensor([-1.0653], requires_grad=True)
# w1:  tensor([[0.4399, 0.2351, 0.5384]], requires_grad=True)
# b1:  tensor([-1.0631], requires_grad=True)
# w1:  tensor([[0.3121, 0.0814, 0.4588]], requires_grad=True)
# b1:  tensor([-1.0653], requires_grad=True)
# w1:  tensor([[0.4362, 0.2306, 0.5361]], requires_grad=True)
# b1:  tensor([-1.0632], requires_grad=True)
# w1:  tensor([[0.3157, 0.0857, 0.4611]], requires_grad=True)
# b1:  tensor([-1.0652], requires_grad=True)
# w1:  tensor([[0.4327, 0.2264, 0.5340]], requires_grad=True)
# b1:  tensor([-1.0632], requires_grad=True)
# w1:  tensor([[0.3191, 0.0898, 0.4632]], requires_grad=True)
# b1:  tensor([-1.0651], requires_grad=True)
# w1:  tensor([[0.4294, 0.2225, 0.5319]], requires_grad=True)
# b1:  tensor([-1.0633], requires_grad=True)
# w1:  tensor([[0.3223, 0.0936, 0.4652]], requires_grad=True)
# b1:  tensor([-1.0651], requires_grad=True)
# w1:  tensor([[0.4263, 0.2187, 0.5300]], requires_grad=True)
# b1:  tensor([-1.0633], requires_grad=True)
# w1:  tensor([[0.3253, 0.0972, 0.4670]], requires_grad=True)
# b1:  tensor([-1.0650], requires_grad=True)
# w1:  tensor([[0.4234, 0.2152, 0.5281]], requires_grad=True)
# b1:  tensor([-1.0634], requires_grad=True)
# w1:  tensor([[0.3282, 0.1007, 0.4688]], requires_grad=True)
# b1:  tensor([-1.0650], requires_grad=True)
# w1:  tensor([[0.4206, 0.2119, 0.5264]], requires_grad=True)
# b1:  tensor([-1.0634], requires_grad=True)
# w1:  tensor([[0.3309, 0.1039, 0.4705]], requires_grad=True)
# b1:  tensor([-1.0649], requires_grad=True)
# w1:  tensor([[0.4180, 0.2087, 0.5248]], requires_grad=True)
# b1:  tensor([-1.0635], requires_grad=True)
# w1:  tensor([[0.3334, 0.1069, 0.4721]], requires_grad=True)
# b1:  tensor([-1.0649], requires_grad=True)
# w1:  tensor([[0.4156, 0.2058, 0.5233]], requires_grad=True)
# b1:  tensor([-1.0635], requires_grad=True)
# w1:  tensor([[0.3358, 0.1098, 0.4735]], requires_grad=True)
# b1:  tensor([-1.0648], requires_grad=True)
# w1:  tensor([[0.4133, 0.2030, 0.5218]], requires_grad=True)
# b1:  tensor([-1.0635], requires_grad=True)
# w1:  tensor([[0.3380, 0.1125, 0.4749]], requires_grad=True)
# b1:  tensor([-1.0648], requires_grad=True)
# w1:  tensor([[0.4111, 0.2004, 0.5205]], requires_grad=True)
# b1:  tensor([-1.0636], requires_grad=True)
# w1:  tensor([[0.3401, 0.1150, 0.4763]], requires_grad=True)
# b1:  tensor([-1.0648], requires_grad=True)
# w1:  tensor([[0.4090, 0.1979, 0.5192]], requires_grad=True)
# b1:  tensor([-1.0636], requires_grad=True)
# w1:  tensor([[0.3421, 0.1174, 0.4775]], requires_grad=True)
# b1:  tensor([-1.0647], requires_grad=True)
# w1:  tensor([[0.4071, 0.1956, 0.5180]], requires_grad=True)
# b1:  tensor([-1.0636], requires_grad=True)
# w1:  tensor([[0.3440, 0.1197, 0.4787]], requires_grad=True)
# b1:  tensor([-1.0647], requires_grad=True)
# w1:  tensor([[0.4053, 0.1934, 0.5168]], requires_grad=True)
# b1:  tensor([-1.0637], requires_grad=True)
# w1:  tensor([[0.3458, 0.1218, 0.4798]], requires_grad=True)
# b1:  tensor([-1.0647], requires_grad=True)
# w1:  tensor([[0.4036, 0.1913, 0.5158]], requires_grad=True)
# b1:  tensor([-1.0637], requires_grad=True)

# %%
pred2 = linear_model(features)

# %%
target
# Out:
# tensor([[59],
#         [45],
#         [54],
#         [58],
#         [42],
#         [49]])

# %%
mse(pred2, target)
# Out:
# tensor(41.6627, grad_fn=<DivBackward0>)

# %%
w1 = w.copy_
b1 = b

# %%
w
# Out:
# tensor([[0.4036, 0.1913, 0.5158]], requires_grad=True)

# %%
inputs = torch.tensor([[73., 67, 43],
                   [91, 88, 64],
                   [87, 134, 58],
                   [102, 43, 37],
                   [69, 96, 70],
                   [74, 66, 43],
                   [91, 87, 65],
                   [88, 134, 59],
                   [101, 44, 37],
                   [68, 96, 71],
                   [73, 66, 44],
                   [92, 87, 64],
                   [87, 135, 57],
                   [103, 43, 36],
                   [68, 97, 70]]
                   )

# %%
targets = torch.tensor([[56, 70],
                    [81, 101],
                    [119, 133],
                    [22, 37],
                    [103, 119],
                    [57, 69],
                    [80, 102],
                    [118, 132],
                    [21, 38],
                    [104, 118],
                    [57, 69],
                    [82, 100],
                    [118, 134],
                    [20, 38],
                    [102, 120]]
                   )

# %%
from torch import nn

# %%
# !pip install torch.utils
# Out:
# Collecting torch.utils
#   Downloading torch-utils-0.1.2.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torch.utils) (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torch.utils) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torch.utils) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torch.utils) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torch.utils) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torch.utils) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->torch.utils) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->torch.utils) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torch.utils) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torch.utils) (1.3.0)
# Building wheels for collected packages: torch.utils
#   Building wheel for torch.utils (setup.py) ... done
#   Created wheel for torch.utils: filename=torch_utils-0.1.2-py3-none-any.whl size=6187 sha256=f3db56bba9b11e4e52f3dc07dde07cba84c5f7ca7ae45936ab85c46204f4938f
#   Stored in directory: /root/.cache/pip/wheels/76/08/f0/378d1fe4aac5aa1e21483918d70b7e3428c4faaac0abda4e15
# Successfully built torch.utils
# Installing collected packages: torch.utils
# Successfully installed torch.utils-0.1.2

# %%
from torch.utils.data import TensorDataset, DataLoader

# %%
train_ds = TensorDataset(inputs, targets)
train_ds[0:3]
# Out:
# (tensor([[ 73.,  67.,  43.],
#          [ 91.,  88.,  64.],
#          [ 87., 134.,  58.]]),
#  tensor([[ 56,  70],
#          [ 81, 101],
#          [119, 133]]))

# %%
batch_size = 5
train_dl = DataLoader(train_ds, batch_size, shuffle=True)

# %%
model = nn.Linear(3, 2)

# %%
model.weight
# Out:
# Parameter containing:
# tensor([[ 0.2406,  0.5310, -0.4234],
#         [-0.4081,  0.2693, -0.3118]], requires_grad=True)

# %%
model.bias
# Out:
# Parameter containing:
# tensor([-0.3061, -0.5491], requires_grad=True)

# %%
preds = model(inputs)
preds
# Out:
# tensor([[ 34.6280, -25.7001],
#         [ 41.2186, -33.9374],
#         [ 67.2236, -18.0443],
#         [ 31.4000, -42.1272],
#         [ 37.6342, -24.6764],
#         [ 34.3375, -26.3775],
#         [ 40.2642, -34.5186],
#         [ 67.0407, -18.7641],
#         [ 31.6904, -41.4497],
#         [ 36.9703, -24.5801],
#         [ 33.6736, -26.2813],
#         [ 40.9281, -34.6148],
#         [ 68.1780, -17.4631],
#         [ 32.0639, -42.2234],
#         [ 37.9247, -23.9989]], grad_fn=<AddmmBackward0>)

# %%
import torch.nn.functional as F

# %%
loss_fn = F.mse_loss

# %%
loss_fn(preds, targets)
# Out:
# tensor(8628.1621, grad_fn=<MseLossBackward0>)

# %%
opt = torch.optim.SGD(model.parameters(), lr = 1e-5)

# %%
def fit(epochs, model, lossfn, opti):

  for epoch in range(epochs):

    # train with batches of data
    for xb, yb in train_dl:

      # generate predictions
      pred = model(xb)

      # calculate loss
      loss = lossfn(pred, yb.float())

      # compute gradients
      loss.backward()

      # update parameters using gradients
      opti.step()

      # reset gradients to zero
      opti.zero_grad()

    # printing progress
    if (epoch+1)%10 == 0:
      print(f"Epoch [{epoch+1}/{epochs}], Loss: {loss.item()}")

# %%
fit(100, model, loss_fn, opt)
# Out:
# Epoch [10/100], Loss: 10.898661613464355
# Epoch [20/100], Loss: 4.862102508544922
# Epoch [30/100], Loss: 5.847952842712402
# Epoch [40/100], Loss: 12.708669662475586
# Epoch [50/100], Loss: 9.848760604858398
# Epoch [60/100], Loss: 9.503044128417969
# Epoch [70/100], Loss: 10.481196403503418
# Epoch [80/100], Loss: 8.024871826171875
# Epoch [90/100], Loss: 6.464609622955322
# Epoch [100/100], Loss: 10.388861656188965

# %%
preds = model(inputs)
preds
# Out:
# tensor([[ 57.0967,  70.4530],
#         [ 80.2032,  99.0128],
#         [122.0512, 136.0134],
#         [ 21.8213,  38.5842],
#         [ 98.0375, 115.2669],
#         [ 55.8128,  69.3455],
#         [ 79.7203,  98.8260],
#         [122.1630, 136.4664],
#         [ 23.1052,  39.6916],
#         [ 98.8385, 116.1876],
#         [ 56.6138,  70.2662],
#         [ 78.9193,  97.9053],
#         [122.5341, 136.2002],
#         [ 21.0203,  37.6635],
#         [ 99.3214, 116.3744]], grad_fn=<AddmmBackward0>)

# %%
targets
# Out:
# tensor([[ 56,  70],
#         [ 81, 101],
#         [119, 133],
#         [ 22,  37],
#         [103, 119],
#         [ 57,  69],
#         [ 80, 102],
#         [118, 132],
#         [ 21,  38],
#         [104, 118],
#         [ 57,  69],
#         [ 82, 100],
#         [118, 134],
#         [ 20,  38],
#         [102, 120]])
